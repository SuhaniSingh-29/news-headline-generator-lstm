# %%
# !pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ip (C:\Users\suhan\AppData\Roaming\Python\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\suhan\AppData\Roaming\Python\Python312\site-packages)
#   WARNING: The script nltk.exe is installed in 'C:\Users\suhan\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: Ignoring invalid distribution ~ip (C:\Users\suhan\AppData\Roaming\Python\Python312\site-packages)
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\suhan\appdata\roaming\python\python312\site-packages (from nltk) (8.1.8)
# Requirement already satisfied: joblib in c:\users\suhan\appdata\roaming\python\python312\site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\suhan\appdata\roaming\python\python312\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\suhan\appdata\roaming\python\python312\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\suhan\appdata\roaming\python\python312\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 11.4 MB/s eta 0:00:00
# Installing collected packages: nltk
# Successfully installed nltk-3.9.1

# %%
import pandas as pd
import numpy as np
import re
import nltk
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\suhan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import zipfile
import os

zip_file_name = "dataset.zip"

with zipfile.ZipFile(zip_file_name, 'r') as zip_ref:
    zip_ref.extractall("news_data") 

os.listdir("news_data")
# Out:
# ['News_Category_Dataset_v3.json']

# %%
df = pd.read_json("news_data/News_Category_Dataset_v3.json", lines=True)
df.head()
# Out:
#                                                 link  \
# 0  https://www.huffpost.com/entry/covid-boosters-...
# 1  https://www.huffpost.com/entry/american-airlin...
# 2  https://www.huffpost.com/entry/funniest-tweets...
# 3  https://www.huffpost.com/entry/funniest-parent...
# 4  https://www.huffpost.com/entry/amy-cooper-lose...
#
#                                             headline   category  \
# 0  Over 4 Million Americans Roll Up Sleeves For O...  U.S. NEWS
# 1  American Airlines Flyer Charged, Banned For Li...  U.S. NEWS
# 2  23 Of The Funniest Tweets About Cats And Dogs ...     COMEDY
# 3  The Funniest Tweets From Parents This Week (Se...  PARENTING
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...  U.S. NEWS
#
#                                    short_description               authors  \
# 0  Health experts said it is too early to predict...  Carla K. Johnson, AP
# 1  He was subdued by passengers and crew when he ...        Mary Papenfuss
# 2  "Until you have a dog you don't understand wha...         Elyse Wanshel
# 3  "Accidentally put grown-up toothpaste on my to...      Caroline Bologna
# 4  Amy Cooper accused investment firm Franklin Te...        Nina Golgowski
#
#         date
# 0 2022-09-23
# 1 2022-09-23
# 2 2022-09-23
# 3 2022-09-23
# 4 2022-09-22

# %%
df = df[['short_description', 'headline']].dropna()

# %%
df.head()
# Out:
#                                    short_description  \
# 0  Health experts said it is too early to predict...
# 1  He was subdued by passengers and crew when he ...
# 2  "Until you have a dog you don't understand wha...
# 3  "Accidentally put grown-up toothpaste on my to...
# 4  Amy Cooper accused investment firm Franklin Te...
#
#                                             headline
# 0  Over 4 Million Americans Roll Up Sleeves For O...
# 1  American Airlines Flyer Charged, Banned For Li...
# 2  23 Of The Funniest Tweets About Cats And Dogs ...
# 3  The Funniest Tweets From Parents This Week (Se...
# 4  Woman Who Called Cops On Black Bird-Watcher Lo...

# %%
df.shape
# Out:
# (209527, 2)

# %%
def clean(text):
    text = text.lower()
    # Allow < and > so tokens like <start> survive
    text = re.sub(r"[^a-zA-Z0-9\s<>]", "", text)
    return text

# %%
df['short_description'] = df['short_description'].apply(clean)
df['headline'] = df['headline'].apply(lambda x: "<start> " + clean(x) + " <end>")

# %%
INPUT_LEN = []
HEADLINE_LEN = []
for i in df.short_description:
    INPUT_LEN.append(len(i.split()))
for i in df.headline:
    HEADLINE_LEN.append(len(i.split()))

# %%
max(INPUT_LEN), max(HEADLINE_LEN)
# Out:
# (243, 45)

# %%
MAX_VOCAB = 15000
MAX_INPUT_LEN = 243
MAX_HEADLINE_LEN = 47       #45+2 (<start> and <end> token)

# %%
#input tokenizer
input_tokenizer = Tokenizer(num_words=MAX_VOCAB, oov_token='<OOV>')
input_tokenizer.fit_on_texts(df['short_description'])
input_seq = input_tokenizer.texts_to_sequences(df['short_description'])
input_pad = pad_sequences(input_seq, maxlen=MAX_INPUT_LEN, padding='post')

# %%
#output tokenizer
output_tokenizer = Tokenizer(
    num_words=MAX_VOCAB,
    oov_token='<OOV>',
    filters='!"#$%&()*+,-./:;=?@[\\]^_`{|}~\t\n'  # allows <start> and <end>
)

# output_tokenizer.fit_on_texts(['<start> <end>'])  
output_tokenizer.fit_on_texts(df['headline'])
output_seq = output_tokenizer.texts_to_sequences(df['headline'])
output_pad = pad_sequences(output_seq, maxlen=MAX_HEADLINE_LEN, padding='post')

# %%
print('<start>' in output_tokenizer.word_index)
print('<end>' in output_tokenizer.word_index)
# Out:
# True
# True

# %%
output_vocab_size = min(MAX_VOCAB, len(output_tokenizer.word_index) + 1)

# %%
decoder_input_data = output_pad[:, :-1]
decoder_target_data = output_pad[:, 1:]
decoder_input_data = pad_sequences(decoder_input_data, maxlen=MAX_HEADLINE_LEN, padding='post')
decoder_target_data = pad_sequences(decoder_target_data, maxlen=MAX_HEADLINE_LEN, padding='post')
decoder_target_data = np.expand_dims(decoder_target_data, -1)

# %%
print(input_pad.shape)
print(decoder_input_data.shape)
print(decoder_target_data.shape)
# Out:
# (209527, 243)
# (209527, 47)
# (209527, 47, 1)

# %%
X_train, X_test, y_train_input, y_test_input, y_train_target, y_test_target = train_test_split(
    input_pad, decoder_input_data, decoder_target_data, test_size=0.2, random_state=42
)

# %%
embedding_dim = 128
lstm_units = 128

# %%
encoder_input = Input(shape=(MAX_INPUT_LEN,))
encoder_emb = Embedding(MAX_VOCAB, embedding_dim)(encoder_input)
encoder_output, state_h, state_c = LSTM(lstm_units, return_state=True)(encoder_emb)

# %%
decoder_input = Input(shape=(MAX_HEADLINE_LEN,))
decoder_emb = Embedding(MAX_VOCAB, embedding_dim)(decoder_input)
decoder_lstm_layer = LSTM(lstm_units, return_sequences=True)
decoder_lstm = LSTM(lstm_units, return_sequences=True)(decoder_emb, initial_state=[state_h, state_c])
decoder_output = Dense(output_vocab_size, activation='softmax')(decoder_lstm)

# %%
model = Model([encoder_input, decoder_input], decoder_output)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ![Seq-2-seq LSTM.png](attachment:02be464a-3ef4-4bc6-b0ac-63e99ce06595.png)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 243)               │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ input_layer_1 (InputLayer)    │ (None, 47)                │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding (Embedding)         │ (None, 243, 128)          │       1,920,000 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ embedding_1 (Embedding)       │ (None, 47, 128)           │       1,920,000 │ input_layer_1[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm (LSTM)                   │ [(None, 128), (None,      │         131,584 │ embedding[0][0]            │
# │                               │ 128), (None, 128)]        │                 │                            │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ lstm_1 (LSTM)                 │ (None, 47, 128)           │         131,584 │ embedding_1[0][0],         │
# │                               │                           │                 │ lstm[0][1], lstm[0][2]     │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 47, 15000)         │       1,935,000 │ lstm_1[0][0]               │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 6,038,168 (23.03 MB)
#  Trainable params: 6,038,168 (23.03 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit([X_train, y_train_input], y_train_target, epochs=5, batch_size=128, validation_split=0.1)
# Out:
# Epoch 1/5
# 1179/1179 ━━━━━━━━━━━━━━━━━━━━ 2676s 2s/step - accuracy: 0.7865 - loss: 2.2993 - val_accuracy: 0.8086 - val_loss: 1.4752
# Epoch 2/5
# 1179/1179 ━━━━━━━━━━━━━━━━━━━━ 2526s 2s/step - accuracy: 0.8094 - loss: 1.4531 - val_accuracy: 0.8121 - val_loss: 1.3961
# Epoch 3/5
# 1179/1179 ━━━━━━━━━━━━━━━━━━━━ 3232s 3s/step - accuracy: 0.8130 - loss: 1.3730 - val_accuracy: 0.8152 - val_loss: 1.3448
# Epoch 4/5
# 1179/1179 ━━━━━━━━━━━━━━━━━━━━ 2759s 2s/step - accuracy: 0.8166 - loss: 1.3168 - val_accuracy: 0.8179 - val_loss: 1.3094
# Epoch 5/5
# 1179/1179 ━━━━━━━━━━━━━━━━━━━━ 2406s 2s/step - accuracy: 0.8191 - loss: 1.2754 - val_accuracy: 0.8193 - val_loss: 1.2848

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')  
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()

# %%
def generate_headline(description, temperature=1.2):
    desc = clean(description)
    seq = input_tokenizer.texts_to_sequences([desc])
    padded_seq = pad_sequences(seq, maxlen=MAX_INPUT_LEN, padding='post')

    start_token = output_tokenizer.word_index.get('<start>')
    end_token = output_tokenizer.word_index.get('<end>')

    if start_token is None or end_token is None:
        raise ValueError("Start or End token not found in tokenizer vocabulary.")

    decoder_input_seq = [start_token]
    predicted_tokens = []

    for _ in range(MAX_HEADLINE_LEN):
        decoder_input_pad = pad_sequences([decoder_input_seq], maxlen=MAX_HEADLINE_LEN, padding='post')
        prediction = model.predict([padded_seq, decoder_input_pad], verbose=0)

        # Apply temperature scaling
        prediction = prediction[0, len(decoder_input_seq)-1]
        prediction = np.log(prediction + 1e-7) / temperature
        prediction = np.exp(prediction) / np.sum(np.exp(prediction))  # Convert back to probabilities
        
        next_token = np.random.choice(range(output_vocab_size), p=prediction)

        if next_token == end_token or next_token == 0:
            break

        predicted_tokens.append(next_token)
        decoder_input_seq.append(next_token)

    headline = ''
    for token in predicted_tokens:
        if token != 0:
            headline += output_tokenizer.index_word.get(token, '<UNK>') + ' '

    return headline.strip()

# %%
sample_description = "Health experts said it is too early to predict whether demand would match up with the 171 million doses of the new boosters the U.S. ordered for the fall."
predicted_headline = generate_headline(sample_description)

print("Input Description:", sample_description)  
print("\nPredicted Headline:", predicted_headline)
# Out:
# Input Description: Health experts said it is too early to predict whether demand would match up with the 171 million doses of the new boosters the U.S. ordered for the fall.
#
# Predicted Headline: arson missile down main 34 site knocks butt lawsuit dental <OOV> in little

# %%
sample_description = "tesla launches new software update for autopilot system"
predicted_headline = generate_headline(sample_description)

print("Input Description:", sample_description)
print("\nPredicted Headline:", predicted_headline)
# Out:
# Input Description: tesla launches new software update for autopilot system
#
# Predicted Headline: almost ramadan parents have a tolerance

# %%
generate_headline("how to increase user engagement on a mobile app")
# Out:
# 'census beyonc wants set to give gates to sea election last his sight'
